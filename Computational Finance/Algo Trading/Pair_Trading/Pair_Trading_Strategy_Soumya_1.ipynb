# %%
import pandas as pd
import datetime
import yfinance as yf

# %%
def get_hist_val(tickers, start_date, end_date):
    data = pd.DataFrame()
    stock_list = list()
    
    for ticker in tickers:
#         data = pd.concat([data, pd.DataFrame(yf.download(ticker, start=datetime(2020, 10, 27), end=datetime(2021, 10, 27)).iloc[:,4])], axis = 1)
        data = pd.concat([data, pd.DataFrame(yf.download(ticker, start=start_date, end=end_date).iloc[:,4])], axis = 1)
        stock_list.append(ticker)
    data.columns = stock_list
    return data

# %%
# Corrected datetime usage
start_dt = datetime.datetime(2020, 10, 27)
end_dt = datetime.datetime(2021, 10, 27)

ticks = ["DPZ", "AAPL", "GOOG", "AMD", "GME", "SPY", "NFLX", "BA", "WMT","TWTR","GS","XOM","NKE","FEYE", "FB","BRK-B", "MSFT"] #Name of company (Dominos pizza)
d = get_hist_val(ticks, start_dt, end_dt)
print(d.shape)
# Most Recent Data
d.tail()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['TWTR']: Exception('%ticker%: No timezone found, symbol may be delisted')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
# from nsetools import Nse

# # Create an instance of Nse class
# nse = Nse()

# # Get Nifty quote
# nifty_quote = nse.get_index_quote("infy")

# print(nifty_quote)

import yfinance as yf
data_nse = yf.download('infy.ns')
print(data_nse)
# data_bse = yf.download('infy.bo')
# print(data_bse)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1996-01-01     0.794921     0.796679     0.791015     0.796679     0.519068
# 1996-01-02     0.794921     0.798828     0.793457     0.793457     0.516969
# 1996-01-03     0.798828     0.798828     0.798828     0.798828     0.520468
# 1996-01-04     0.791015     0.794921     0.791015     0.793554     0.517032
# 1996-01-05     0.784179     0.784179     0.784179     0.784179     0.510924
# ...                 ...          ...          ...          ...          ...
# 2023-08-11  1392.000000  1396.849976  1367.050049  1371.849976  1371.849976
# 2023-08-14  1371.849976  1395.000000  1365.599976  1393.550049  1393.550049
# 2023-08-16  1410.800049  1419.949951  1405.400024  1418.500000  1418.500000
# 2023-08-17  1420.000000  1420.000000  1406.000000  1411.550049  1411.550049
# ...

# %%
# Define the stock symbol (e.g., 'AAPL' for Apple Inc.)
stock_symbol = 'tcs.bo'

# Create a Ticker object for the stock
stock = yf.Ticker(stock_symbol)

# Get the stock's summary information
stock_info = stock.info

# Print the summary information
print("Stock Symbol:", stock_info['symbol'])
print("Company Name:", stock_info['longName'])
print("Sector:", stock_info['sector'])
print("Industry:", stock_info['industry'])
print("Market Capitalization:", stock_info['marketCap'])
print("Dividend Yield:", stock_info['dividendYield'])
print("P/B:", stock_info['priceToBook'])
print("PE:", stock_info['trailingPE'])
print("EPS:", stock_info['trailingEps'])
# Out:
# Stock Symbol: TCS.BO
# Company Name: Tata Consultancy Services Limited
# Sector: Technology
# Industry: Information Technology Services
# Market Capitalization: 12327147536384
# Dividend Yield: 0.014199999
# P/B: 13.272469
# PE: 28.167028
# EPS: 119.56

# %%
# stock_info

# %% [markdown]
# <h4>Get NSE 200 stocks</h4>

# %%
# import requests
# from bs4 import BeautifulSoup

# # URL of the page with Nifty 200 company list
# # url = "https://www.moneycontrol.com/stocks/marketstats/indexcomp.php?optex=NSE&opttopic=indexcomp&index=9"

# url = 'https://www.moneycontrol.com/stocks/marketstats/indexcomp.php?optex=NSE&opttopic=indexcomp&index=49'

# # Send an HTTP GET request to the URL
# response = requests.get(url)

# # Parse the HTML content using Beautiful Soup
# soup = BeautifulSoup(response.content, 'html.parser')

# # Find the table containing company information
# table = soup.find('table', {'class': 'tbldata14 bdrtpg'})

# # Loop through rows and extract company names
# company_data = []
# for row in table.find_all('tr')[1:]:  # Skip the header row
#     cols = row.find_all('td')
#     if len(cols) >= 3:
#         company_name = cols[1].text.strip()
#         company_symbol = cols[0].text.strip()
#         company_data.append((company_name, company_symbol))
        
# # Print the list of company names & their symbols
# for name, symbol in company_data:
#     print(f"Name: {name}, Symbol: {symbol}")

# %%
# import requests
# from bs4 import BeautifulSoup

# # url = "https://www1.nseindia.com/live_market/dynaContent/live_watch/equities_stock_watch.htm?index=9"
# url = 'https://www.nseindia.com/market-data/live-equity-market?symbol=NIFTY%20200'
# headers = {
#     "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
# }

# response = requests.get(url, headers=headers)
# soup = BeautifulSoup(response.content, 'html.parser')

# company_data = []

# table = soup.find('table', {'id': 'dataTable'})

# for row in table.find_all('tr')[1:]:  # Skip the header row
#     cols = row.find_all('td')
#     if len(cols) >= 3:
#         company_name = cols[0].text.strip()
#         company_symbol = cols[1].text.strip()
#         company_data.append((company_name, company_symbol))

# for name, symbol in company_data:
#     print(f"Name: {name}, Symbol: {symbol}")

# %%
# table

# %%
nse_200 = pd.read_csv('MW-NIFTY-200-20-Aug-2023.CSV',skiprows=[1])
nse_200.columns = nse_200.columns.str.strip()
print(nse_200)
# Out:
#          SYMBOL       OPEN       HIGH        LOW PREV. CLOSE        LTP  \
# 0    ADANIGREEN     940.55   1,024.95     938.15       933.5        999
# 1    ADANIPOWER     286.95     321.65     286.25      286.55      304.6
# 2    ADANITRANS      824.9        894     824.75       822.2     870.25
# 3       CGPOWER      414.5        432        414       412.4      430.8
# 4           AWL      368.1     393.55        367       368.1      382.5
# ..          ...        ...        ...        ...         ...        ...
# 195       GLAND   1,617.25   1,631.25   1,521.65    1,617.55   1,575.00
# 196     PAGEIND  41,020.00  41,020.05  39,739.90   41,270.75  40,106.70
# 197      NAUKRI   4,296.00   4,296.00   4,177.70    4,298.90   4,185.00
# 198      ASTRAL   1,987.40   1,987.40   1,920.00    1,991.70   1,936.00
# 199  BAJAJHLDNG   7,150.45   7,215.95   6,900.00    7,147.00   6,930.00
#
#           CHNG  %CHNG VOLUME \n(shares)               VALUE      52W H  \
# ...

# %% [markdown]
# <h4>Clustering of Stocks based on Sector, market Cap & PE Ratio</h4>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import yfinance as yf

# Define a list of stock symbols
stock_symbols = []
# stock_symbols = ['AAPL', 'GOOGL', 'AMZN', 'MSFT', 'TSLA']
for sym in nse_200['SYMBOL']:
    stock_symbols.append(sym+'.NS')
    

# stock_symbols

# %%
# Create a DataFrame to store the data
stock_data = pd.DataFrame(columns=['Symbol', 'Sector', 'MarketCap', 'PERatio'])

# Populate the DataFrame with stock information
for symbol in stock_symbols:
    stock = yf.Ticker(symbol)
    info = stock.info
    stock_data.loc[len(stock_data)] = [symbol, info.get('sector', 'Unknown'), info.get('marketCap', np.nan), info.get('trailingPE', np.nan)]
#     stock_data = stock_data.append({
#         'Symbol': symbol,
#         'Sector': info.get('sector', 'Unknown'),
#         'MarketCap': info.get('marketCap', np.nan),
#         'PERatio': info.get('trailingPE', np.nan),
#     }, ignore_index=True)

# Drop rows with missing values
stock_data.dropna(inplace=True)

# %%
stock_data['Sector'].unique()
# Out:
# array(['Utilities', 'Industrials', 'Consumer Defensive', 'Energy',
#        'Financial Services', 'Basic Materials', 'Consumer Cyclical',
#        'Real Estate', 'Healthcare', 'Technology',
#        'Communication Services'], dtype=object)

# %%
stock_data_onehot = pd.get_dummies(stock_data, columns=['Sector'], prefix=['Sector'])

print(stock_data_onehot)
# Out:
#             Symbol      MarketCap     PERatio  Cluster  \
# 0    ADANIGREEN.NS  1577305374720  166.346160        0
# 1    ADANIPOWER.NS  1175070703616   12.597188        0
# 2    ADANITRANS.NS   972595789824   73.023450        0
# 3       CGPOWER.NS   656174350336   83.589490        0
# 4           AWL.NS   496599957504   85.639015        0
# ..             ...            ...         ...      ...
# 194       LUPIN.NS   485860474880  113.093220        0
# 195       GLAND.NS   258366439424   31.897112        0
# 196     PAGEIND.NS   449571258368   78.531586        0
# 198      ASTRAL.NS   521147744256  117.939200        0
# 199  BAJAJHLDNG.NS   772736548864   15.927328        0
#
#      Sector_Basic Materials  Sector_Communication Services  \
# 0                     False                          False
# 1                     False                          False
# 2                     False                          False
# 3                     False                          False
# ...

# %%
# Normalize the data
scaler = StandardScaler()
normalized_data = scaler.fit_transform(stock_data[['MarketCap', 'PERatio']])

# %%
# normalized_data

stock_data_onehot[['MarketCap', 'PERatio']] = scaler.fit_transform(stock_data_onehot[['MarketCap', 'PERatio']])
stock_data_onehot
# Out:
#             Symbol  MarketCap   PERatio  Cluster  Sector_Basic Materials  \
# 0    ADANIGREEN.NS   0.174132  0.799739        0                   False
# 1    ADANIPOWER.NS  -0.025058 -0.308493        0                   False
# 2    ADANITRANS.NS  -0.125326  0.127063        0                   False
# 3       CGPOWER.NS  -0.282021  0.203224        0                   False
# 4           AWL.NS  -0.361044  0.217997        0                   False
# ..             ...        ...       ...      ...                     ...
# 194       LUPIN.NS  -0.366362  0.415889        0                   False
# 195       GLAND.NS  -0.479019 -0.169378        0                   False
# 196     PAGEIND.NS  -0.384333  0.166766        0                   False
# 198      ASTRAL.NS  -0.348887  0.450819        0                   False
# 199  BAJAJHLDNG.NS  -0.224298 -0.284489        0                   False
#
#      Sector_Communication Services  Sector_Consumer Cyclical  \
# ...

# %%
# Perform K-means clustering
num_clusters = 3  # You can choose the number of clusters
kmeans = KMeans(n_clusters=num_clusters, random_state=0)
# stock_data['Cluster'] = kmeans.fit_predict(normalized_data)
stock_data_onehot['Cluster'] = kmeans.fit_predict(stock_data_onehot.iloc[:, 1:])

# # Print the clustered stocks
# for cluster_id in range(num_clusters):
#     cluster_stocks = stock_data[stock_data['Cluster'] == cluster_id]['Symbol']
#     print(f"Cluster {cluster_id + 1} Stocks: {', '.join(cluster_stocks)}")

stock_data_onehot
# Out:
# C:\Users\0394D9744\Anaconda3\envs\mtech\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#             Symbol  MarketCap   PERatio  Cluster  Sector_Basic Materials  \
# 0    ADANIGREEN.NS   0.174132  0.799739        0                   False
# 1    ADANIPOWER.NS  -0.025058 -0.308493        0                   False
# 2    ADANITRANS.NS  -0.125326  0.127063        0                   False
# 3       CGPOWER.NS  -0.282021  0.203224        0                   False
# 4           AWL.NS  -0.361044  0.217997        0                   False
# ..             ...        ...       ...      ...                     ...
# 194       LUPIN.NS  -0.366362  0.415889        0                   False
# 195       GLAND.NS  -0.479019 -0.169378        0                   False
# ...

# %%
stock_data_onehot['Cluster'].unique()
# Out:
# array([0, 2, 1])

# %%
stock_data_onehot.iloc[:,1:]
# Out:
#      MarketCap   PERatio  Cluster  Sector_Basic Materials  \
# 0     0.174132  0.799739        0                   False
# 1    -0.025058 -0.308493        0                   False
# 2    -0.125326  0.127063        0                   False
# 3    -0.282021  0.203224        0                   False
# 4    -0.361044  0.217997        0                   False
# ..         ...       ...      ...                     ...
# 194  -0.366362  0.415889        0                   False
# 195  -0.479019 -0.169378        0                   False
# 196  -0.384333  0.166766        0                   False
# 198  -0.348887  0.450819        0                   False
# 199  -0.224298 -0.284489        0                   False
#
#      Sector_Communication Services  Sector_Consumer Cyclical  \
# 0                            False                     False
# 1                            False                     False
# 2                            False                     False
# ...

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# X is your data
# X = stock_data.iloc[:,2:-1]
X = stock_data_onehot.iloc[:,1:]
wcss = []
for i in range(1, 31):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 31), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# import matplotlib.pyplot as plt

# # Perform K-means clustering
# num_clusters = 3  # You can choose the number of clusters
# kmeans = KMeans(n_clusters=num_clusters, random_state=0)
# stock_data['Cluster'] = kmeans.fit_predict(normalized_data)

# # Create scatter plots for visualization
# plt.figure(figsize=(10, 6))

# for cluster_id in range(num_clusters):
#     cluster_stocks = stock_data[stock_data['Cluster'] == cluster_id]
#     plt.scatter(cluster_stocks['MarketCap'], cluster_stocks['PERatio'], label=f'Cluster {cluster_id + 1}')
#     for _, row in cluster_stocks.iterrows():
# #         plt.annotate(row['Symbol'], (row['MarketCap'], row['PERatio']), textcoords="offset points", xytext=(0, 5), ha='center')
#         plt.annotate(f"{row['Symbol']} ({row['MarketCap']:.2f}, {row['PERatio']:.2f})", 
#                      (row['MarketCap'], row['PERatio']), textcoords="offset points", xytext=(0, 5), ha='center')

# plt.xlabel('Normalized Market Cap')
# plt.ylabel('Normalized PE Ratio')
# plt.title('Cluster Visualization')
# plt.legend()
# plt.show()

# %%
import matplotlib.pyplot as plt

# Perform K-means clustering
num_clusters = 10  # You can choose the number of clusters
kmeans = KMeans(n_clusters=num_clusters, random_state=0)
stock_data_onehot['Cluster'] = kmeans.fit_predict(stock_data_onehot.iloc[:,1:])

# Create scatter plots for visualization
plt.figure(figsize=(10, 6))

for cluster_id in range(num_clusters):
    cluster_stocks = stock_data_onehot[stock_data['Cluster'] == cluster_id]
    plt.scatter(cluster_stocks['MarketCap'], cluster_stocks['PERatio'], label=f'Cluster {cluster_id + 1}')
#     for _, row in cluster_stocks.iterrows():
# #         plt.annotate(row['Symbol'], (row['MarketCap'], row['PERatio']), textcoords="offset points", xytext=(0, 5), ha='center')
#         plt.annotate(f"{row['Symbol']} ({row['MarketCap']:.2f}, {row['PERatio']:.2f})", 
#                      (row['MarketCap'], row['PERatio']), textcoords="offset points", xytext=(0, 5), ha='center')

plt.xlabel('Normalized Market Cap')
plt.ylabel('Normalized PE Ratio')
plt.title('Cluster Visualization')
plt.legend()
plt.show()
# Out:
# C:\Users\0394D9744\Anaconda3\envs\mtech\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
stock_data_onehot[stock_data_onehot['Cluster'] == 8]
# Out:
#             Symbol  MarketCap   PERatio  Cluster  Sector_Basic Materials  \
# 41   HINDUNILVR.NS   2.367474  0.027172        8                   False
# 51          ITC.NS   2.118635 -0.193246        8                   False
# 66   BHARTIARTL.NS   1.854402  0.022861        8                   False
# 69         SBIN.NS   1.925219 -0.333026        8                   False
# 75    ICICIBANK.NS   2.686913 -0.256119        8                   False
# 107          LT.NS   1.231970 -0.145484        8                   False
# 178        INFY.NS   2.343450 -0.221202        8                   False
#
#      Sector_Communication Services  Sector_Consumer Cyclical  \
# 41                           False                     False
# 51                           False                     False
# 66                            True                     False
# 69                           False                     False
# 75                           False                     False
# ...

# %%
tckr = 'GOOG'
start_d = datetime.datetime(2022, 8, 15)
end_d = datetime.datetime(2023, 8, 15)
df_test = pd.DataFrame(yf.download(tckr, start=start_d, end=end_d))
df_test
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-08-15  122.209999  123.260002  121.570000  122.879997  122.879997
# 2022-08-16  122.320000  123.227997  121.535004  122.510002  122.510002
# 2022-08-17  120.930000  122.150002  120.199997  120.320000  120.320000
# 2022-08-18  120.230003  121.690002  119.550003  120.860001  120.860001
# 2022-08-19  119.870003  120.000000  117.669998  118.120003  118.120003
# ...                ...         ...         ...         ...         ...
# 2023-08-08  130.979996  131.940002  130.130005  131.839996  131.839996
# 2023-08-09  132.190002  132.470001  129.505005  130.149994  130.149994
# 2023-08-10  131.970001  132.647003  130.035004  130.210007  130.210007
# 2023-08-11  129.201996  130.440002  128.750000  130.169998  130.169998
# 2023-08-14  129.850006  131.910004  129.589996  131.830002  131.830002
#
#               Volume
# Date
# ...

# %%
corr_matrix = d.corr()
corr_matrix
# Out:
#             DPZ      AAPL      GOOG       AMD       GME       SPY      NFLX  \
# DPZ    1.000000  0.818148  0.874797  0.665388  0.469130  0.834557  0.372663
# AAPL   0.818148  1.000000  0.817185  0.788684  0.430274  0.832325  0.659199
# GOOG   0.874797  0.817185  1.000000  0.572945  0.717871  0.978253  0.542024
# AMD    0.665388  0.788684  0.572945  1.000000  0.076881  0.555607  0.697511
# GME    0.469130  0.430274  0.717871  0.076881  1.000000  0.737520  0.240664
# SPY    0.834557  0.832325  0.978253  0.555607  0.737520  1.000000  0.532301
# NFLX   0.372663  0.659199  0.542024  0.697511  0.240664  0.532301  1.000000
# BA     0.080836  0.095350  0.332867 -0.128145  0.562551  0.442483 -0.031222
# WMT    0.407599  0.373089  0.120376  0.555587 -0.303936  0.118445  0.105738
# TWTR        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# GS     0.724772  0.729216  0.933673  0.447324  0.803210  0.964367  0.480084
# ...

# %%
# Ploting of correlation via heatmap
import seaborn as sn
from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=100)
sn.heatmap(corr_matrix, annot = True)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
figure(figsize=(8, 6), dpi=100)
SPY = d['SPY'] # S&P 500
BRK_A = d['BRK-B'] # Berkshire Class A share
# HOWEVER, let's check out the relationship between the stocks...
plt.plot(SPY, label = "S&P 100")
plt.plot(BRK_A, label = "Berkshire Hathaway")
plt.legend()
# oh... that's why the correlation seem very high. The data are not 'standardized.'
# Let's look at a different one...

# %%
# Correlation of Nike and Apple ~ 0.89.
figure(figsize=(8, 6), dpi=100)
BRK_B = d['BRK-B']
MSFT = d['MSFT']
plt.plot(BRK_B, label = "BRK_B")
plt.plot(MSFT, label = "MSFT")
plt.title('Historical Adjusted Closing Prices')
plt.legend()
# More reasonable.

# %%
# plot the spread
figure(figsize=(8, 6), dpi=100)
plt.plot(BRK_B - MSFT, label = 'Spread (BRK-B - MSFT)')
plt.legend()
plt.title("Spread between BRK-B and MSFT")
# Out:
# Text(0.5, 1.0, 'Spread between BRK-B and MSFT')

# %%
# Check out the cointegration value: Null hyp. = no cointegration
import statsmodels.tsa.stattools as ts 
result = ts.coint(BRK_B, MSFT)

# %%
# Cointegration test: A technique used to find a potential correlation in a time series (long term)
# Determines if the spread between the two assets are constant over time.
# Null Hypothesis: Spread between series are non-stationary.
# Uses the augmented Engle-Granger two-step cointegration test.
cointegration_t_statistic = result[0]
p_val = result[1]
critical_values_test_statistic_at_1_5_10 = result[2]
print('We want the P val < 0.05 (meaning that cointegration exists)')
print('P value for the augmented Engle-Granger two-step cointegration test is', p_val)
# Out:
# We want the P val < 0.05 (meaning that cointegration exists)
# P value for the augmented Engle-Granger two-step cointegration test is 0.4266674594922752

# %%
from statsmodels.tsa.stattools import adfuller
# Compute the ADF test for Berkshire Hathaway and Microsoft
# With all time series, you want to have stationary data otherwise our data will be very hard to predict.
# ADF for Berkshire Hathaway Class B
BRK_B_ADF = adfuller(BRK_B)
print('P value for the Augmented Dickey-Fuller Test is', BRK_B_ADF[1])
MSFT_ADF = adfuller(MSFT)
print('P value for the Augmented Dickey-Fuller Test is', MSFT_ADF[1])
Spread_ADF = adfuller(BRK_B - MSFT)
print('P value for the Augmented Dickey-Fuller Test is', Spread_ADF[1])
Ratio_ADF = adfuller(BRK_B / MSFT)
print('P value for the Augmented Dickey-Fuller Test is', Ratio_ADF[1])
# Spread looks fine. If you'd want even better results, consider taking the difference (order 1) of Berkshire and MSFT

# Results: can only claim stationary for the spread (since P value < 0.05). This suggests a constant mean over time.
# Therefore, the two series are cointegrated.
# Out:
# P value for the Augmented Dickey-Fuller Test is 0.3736745954764994
# P value for the Augmented Dickey-Fuller Test is 0.9132528813894876
# P value for the Augmented Dickey-Fuller Test is 0.5477921687127312
# P value for the Augmented Dickey-Fuller Test is 0.4440159475191213

# %%
# Also, we can take a look at the price ratios between the two time series.
figure(figsize=(8, 6), dpi=100)
ratio = BRK_B / MSFT
plt.plot(ratio, label = 'Price Ratio (BRK / MSFT))')
plt.axhline(ratio.mean(), color='red')
plt.legend()
plt.title("Price Ratio between BRK and MSFT")
# Out:
# Text(0.5, 1.0, 'Price Ratio between BRK and MSFT')

# %%
# NOTE, here you can either use the spread OR the Price ratio approach. Anyways, let's standardize the ratio so we can have a 
# upper and lower bound to help evaluate our trends.. Let's stick with the ratio data.
figure(figsize=(8, 6), dpi=100)
# Calculate the Zscores of each row.
df_zscore = (ratio - ratio.mean())/ratio.std()
plt.plot(df_zscore, label = "Z Scores")
plt.axhline(df_zscore.mean(), color = 'black')
plt.axhline(1.0, color='red') # Setting the upper and lower bounds to be the z score of 1 and -1 (1/-1 standard deviation)
plt.axhline(1.25, color='red') # 95% of our data will lie between these bounds.
plt.axhline(-1.0, color='green') # 68% of our data will lie between these bounds.
plt.axhline(-1.25, color='green') # 95% of our data will lie between these bounds.
plt.legend(loc = 'best')
plt.title('Z score of Ratio of Berkshire to MSFT')
plt.show()
# For the most part, the range that exists outside of these 'bands' must come converge back to the mean. Thus, you can 
# determine when you can go long or short the pair (BRK_B to MSFT).

# %%
# That's cool.. so when do we actually start trading? We need some form of 'signal' to trade (and to trade)
# This is where it can become an 'artform' AND a probability game.

# You could split 80 / 20 for train and test, BUT we are not going to be backtesting since we are just going over the model.
# train = ratio[0:round(0.8*len(ratio))]
# test = ratio[round(0.8*len(ratio)):]
# print('Do the splits check out?',len(train) + len(test) == len(ratio))

# %%
figure(figsize=(8, 6), dpi=100)
ratios_mavg5 = ratio.rolling(window=5, center=False).mean()
ratios_mavg20 = ratio.rolling(window=20, center=False).mean()
std_20 = ratio.rolling(window=20, center=False).std()
zscore_20_5 = (ratios_mavg5 - ratios_mavg20)/std_20
plt.plot(ratio.index, ratio.values)
plt.plot(ratios_mavg5.index, ratios_mavg5.values)
plt.plot(ratios_mavg20.index, ratios_mavg20.values)
plt.legend(['Ratio', '5d Ratio MA', '20d Ratio MA'])
plt.xlabel('Date')
plt.ylabel('Ratio')
plt.title('Ratio between BRB-B and MSFT with 5 day and 20 day Moving Averages')
plt.show()

# %%
figure(figsize=(8, 6), dpi=100)
zscore_20_5.plot()
plt.axhline(0, color='black')
plt.axhline(1, color='red', linestyle='--')
plt.axhline(1.25, color='red', linestyle='--')
plt.axhline(-1, color='green', linestyle='--')
plt.axhline(-1.25, color='green', linestyle='--')
plt.legend(['Rolling Ratio z-score', 'Mean', '+1','+1.25','-1','-1.25'])
plt.show()

# %%
figure(figsize=(8, 6), dpi=100)
ratio.plot()
buy = ratio.copy()
sell = ratio.copy()
buy[zscore_20_5>-1] = 0
sell[zscore_20_5<1] = 0
buy.plot(color='g', linestyle='None', marker='^')
sell.plot(color='r', linestyle='None', marker='^')
x1, x2, y1, y2 = plt.axis()
plt.axis((x1, x2, ratio.min(), ratio.max()))
plt.legend(['Ratio', 'Buy Signal', 'Sell Signal'])
plt.title('Relationship BRK to MSFT')
plt.show()
